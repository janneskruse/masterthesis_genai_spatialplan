# %% [markdown]
# # Create a set of urban regions with names and bounding boxes for the data collection
#
# To create the set, the Urban Centre database is taken as a base:
# https://human-settlement.emergency.copernicus.eu/ucdb2024visual.php#
#
# Specifically, the GHSL thematic data layer is downloaded and processed

# %% [markdown]
# ## Import libraries

# %%
## Import libraries
# system
import os
import multiprocessing as mp
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import RLock
from dotenv import load_dotenv

# data manipulation
import json
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import box

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

p=os.popen('git rev-parse --show-toplevel')
repo_dir = p.read().strip()
p.close()

# %% [markdown]
# ## Process the GHSL data

# %% [markdown]
# read GHSL data

# %%
os.chdir(repo_dir)
ghsl_df= gpd.read_file("data/ghsl/GHS_UCDB_THEME_GHSL_GLOBE_R2024A_V1_0/GHS_UCDB_THEME_GHSL_GLOBE_R2024A.gpkg")
# Out:
# c:\Users\janne\anaconda3\envs\genaiSpatialplan\Lib\site-packages\pyogrio\geopandas.py:275: UserWarning: More than one layer found in 'GHS_UCDB_THEME_GHSL_GLOBE_R2024A.gpkg': 'GHS_UCDB_THEME_GHSL_GLOBE_R2024A' (default), 'UC_centroids'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %% [markdown]
# save as parquet for faster read in the future

# %%
ghsl_df.to_parquet("data/ghsl/ghsl_data.parquet", index=False)

# %%
ghsl_df = gpd.read_parquet("data/ghsl/ghsl_data.parquet")
ghsl_df.head(2)
# Out:
#    ID_UC_G0 GC_UCN_MAI_2025 GC_CNT_GAD_2025  GC_UCA_KM2_2025  GC_POP_TOT_2025  \
# 0         1            Apia           Samoa               35      60041.65661
# 1         2      Nuku'alofa           Tonga               20      51990.76620
#
#   GC_DEV_WIG_2025 GC_DEV_USR_2025  GH_BUS_TOT_1975  GH_BUS_TOT_1980  \
# 0    Lower Middle         Oceania          1984866          2284807
# 1    Upper Middle         Oceania          1700175          1921455
#
#    GH_BUS_TOT_1985  ...  GH_XST_D11_2025  GH_XST_D12_2025  GH_XST_D13_2025  \
# 0          2600248  ...                0                0                0
# 1          2142709  ...                0                0                0
#
#    GH_XST_D21_2025  GH_XST_D22_2025  GH_XST_D23_2025  GH_XST_D30_2025  \
# 0                0                0                0      2296.099859
# 1                0                0                0      3941.202447
#
#    GH_L30_2025  GH_W30_2025                                           geometry
# 0     26.14941      8.85059  MULTIPOLYGON (((-16906000 -1703000, -16905000 ...
# 1     13.19160      6.80840  MULTIPOLYGON (((-16819000 -2590000, -16817000 ...
#
# [2 rows x 552 columns]

# %% [markdown]
# plot the first German city

# %%
ghsl_df[ghsl_df["GC_CNT_GAD_2025"] == "Germany"].iloc[0:1].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea3fb8c5ce4cdd25007ab2605478b8aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea3fb8c5ce4cdd25007ab2605478b8aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea3fb8c5ce4cdd25007ab2605478b8aa = L.map(
#                 &quot;map_ea3fb8c5ce4cdd25007ab2605478b8aa&quot;,
#                 {
#                     center: [50.780886532199915, 6.0967287690906815],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ea3fb8c5ce4cdd25007ab2605478b8aa);
#
#
#
#
#
#             var tile_layer_c5ecbb4f8dfdb4365c020ee9947cb82c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5ecbb4f8dfdb4365c020ee9947cb82c.addTo(map_ea3fb8c5ce4cdd25007ab2605478b8aa);
#
#
#             map_ea3fb8c5ce4cdd25007ab2605478b8aa.fitBounds(
#                 [[50.74245718604189, 6.016242448619531], [50.81931587835794, 6.177215089561832]],
#                 {}
#             );
#
#
#         function geo_json_cea41f1712132aead52ed54ab2d729f7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_cea41f1712132aead52ed54ab2d729f7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cea41f1712132aead52ed54ab2d729f7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_cea41f1712132aead52ed54ab2d729f7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_cea41f1712132aead52ed54ab2d729f7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_cea41f1712132aead52ed54ab2d729f7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_cea41f1712132aead52ed54ab2d729f7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_cea41f1712132aead52ed54ab2d729f7 = L.geoJson(null, {
#                 onEachFeature: geo_json_cea41f1712132aead52ed54ab2d729f7_onEachFeature,
#
#                 style: geo_json_cea41f1712132aead52ed54ab2d729f7_styler,
#                 pointToLayer: geo_json_cea41f1712132aead52ed54ab2d729f7_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_cea41f1712132aead52ed54ab2d729f7_add (data) {
#             geo_json_cea41f1712132aead52ed54ab2d729f7
#                 .addData(data);
#         }
#             geo_json_cea41f1712132aead52ed54ab2d729f7_add({&quot;bbox&quot;: [6.016242448619531, 50.74245718604189, 6.177215089561832, 50.81931587835794], &quot;features&quot;: [{&quot;bbox&quot;: [6.016242448619531, 50.74245718604189, 6.177215089561832, 50.81931587835794], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[6.0733053421722545, 50.80970599463873], [6.086594850579633, 50.80970599463873], [6.085804378291991, 50.80009683938068], [6.1522432907187605, 50.80009683938068], [6.15304239261653, 50.80970599463873], [6.166331901023908, 50.80970599463873], [6.163930756035892, 50.78088071285597], [6.177215089561832, 50.78088071285597], [6.174012912661615, 50.74245718604189], [6.14745801841361, 50.74245718604189], [6.148254453791138, 50.75206197783386],

# %% [markdown]
# create a new dataset (with the country and region names and bounding boxes)

# %%
#copy the relevant columns and rename
ghsl_df_new = ghsl_df[["ID_UC_G0", "GC_UCN_MAI_2025", "GC_CNT_GAD_2025", "geometry"]].copy()
ghsl_df_new.rename(columns={
    "GC_UCN_MAI_2025": "region_name",
    "GC_CNT_GAD_2025": "country_name"
}, inplace=True)

# reproject to EPSG:4326
ghsl_df_new = ghsl_df_new.to_crs(epsg=4326)

# create bounding boxes
ghsl_df_new["bbox"] = ghsl_df_new["geometry"].apply(lambda geom: box(*geom.bounds))

ghsl_df_new.head(2)
# Out:
#    ID_UC_G0 region_name country_name  \
# 0         1        Apia        Samoa
# 1         2  Nuku'alofa        Tonga
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-171.77356 -13.8248, -171.7633...
# 1  MULTIPOLYGON (((-175.19374 -21.13139, -175.172...
#
#                                                 bbox
# 0  POLYGON ((-171.73291 -13.85752, -171.73291 -13...
# 1  POLYGON ((-175.16856 -21.16461, -175.16856 -21...

# %%
map = gpd.GeoDataFrame(geometry=ghsl_df_new.head(1).bbox).explore(color="#ffffff")
ghsl_df_new.head(1).explore(m=map, color="#ff0000", add_to_map=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82afd9c13c02233051ea376941b8c1e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82afd9c13c02233051ea376941b8c1e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82afd9c13c02233051ea376941b8c1e6 = L.map(
#                 &quot;map_82afd9c13c02233051ea376941b8c1e6&quot;,
#                 {
#                     center: [-13.832983420491274, -171.78744792892041],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_82afd9c13c02233051ea376941b8c1e6);
#
#
#
#
#
#             var tile_layer_91f458b63db20d543a69527970202575 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91f458b63db20d543a69527970202575.addTo(map_82afd9c13c02233051ea376941b8c1e6);
#
#
#             map_82afd9c13c02233051ea376941b8c1e6.fitBounds(
#                 [[-13.857521251324338, -171.8419825786271], [-13.808445589658213, -171.73291327921376]],
#                 {}
#             );
#
#
#         function geo_json_0e6e9678c46dee973a87b2e930f4cb04_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#ffffff&quot;, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0e6e9678c46dee973a87b2e930f4cb04_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0e6e9678c46dee973a87b2e930f4cb04_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0e6e9678c46dee973a87b2e930f4cb04_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0e6e9678c46dee973a87b2e930f4cb04_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0e6e9678c46dee973a87b2e930f4cb04.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0e6e9678c46dee973a87b2e930f4cb04_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0e6e9678c46dee973a87b2e930f4cb04 = L.geoJson(null, {
#                 onEachFeature: geo_json_0e6e9678c46dee973a87b2e930f4cb04_onEachFeature,
#
#                 style: geo_json_0e6e9678c46dee973a87b2e930f4cb04_styler,
#                 pointToLayer: geo_json_0e6e9678c46dee973a87b2e930f4cb04_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_0e6e9678c46dee973a87b2e930f4cb04_add (data) {
#             geo_json_0e6e9678c46dee973a87b2e930f4cb04
#                 .addData(data);
#         }
#             geo_json_0e6e9678c46dee973a87b2e930f4cb04_add({&quot;bbox&quot;: [-171.8419825786271, -13.857521251324338, -171.732913

# %% [markdown]
# save as parquet

# %%
ghsl_df_new.to_parquet("data/processed/ghsl_regions.parquet", index=False)

# %%
ghsl_df_new = gpd.read_parquet("data/processed/ghsl_regions.parquet")
ghsl_df_new.head(2)
# Out:
#    ID_UC_G0 region_name country_name  \
# 0         1        Apia        Samoa
# 1         2  Nuku'alofa        Tonga
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-171.77356 -13.8248, -171.7633...
# 1  MULTIPOLYGON (((-175.19374 -21.13139, -175.172...
#
#                                                 bbox
# 0  POLYGON ((-171.73291 -13.85752, -171.73291 -13...
# 1  POLYGON ((-175.16856 -21.16461, -175.16856 -21...

# %% [markdown]
# plot for Leipzig

# %%
# Create GeoDataFrame
bbox_gdf = gpd.GeoDataFrame(geometry=ghsl_df_new[ghsl_df_new["region_name"]=="Leipzig"].bbox, crs="EPSG:4326")

bbox_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_056e36619396dd6f77f3343f40cb1943 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_056e36619396dd6f77f3343f40cb1943&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_056e36619396dd6f77f3343f40cb1943 = L.map(
#                 &quot;map_056e36619396dd6f77f3343f40cb1943&quot;,
#                 {
#                     center: [51.33453717560941, 12.37450346937582],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_056e36619396dd6f77f3343f40cb1943);
#
#
#
#
#
#             var tile_layer_631a2becc218d1065cd2e03466a1a16a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_631a2becc218d1065cd2e03466a1a16a.addTo(map_056e36619396dd6f77f3343f40cb1943);
#
#
#             map_056e36619396dd6f77f3343f40cb1943.fitBounds(
#                 [[51.26216406790087, 12.244877029138685], [51.40691028331796, 12.504129909612955]],
#                 {}
#             );
#
#
#         function geo_json_6723416e2b11ee2d2c62bc36375f5da4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6723416e2b11ee2d2c62bc36375f5da4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6723416e2b11ee2d2c62bc36375f5da4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6723416e2b11ee2d2c62bc36375f5da4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6723416e2b11ee2d2c62bc36375f5da4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6723416e2b11ee2d2c62bc36375f5da4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6723416e2b11ee2d2c62bc36375f5da4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6723416e2b11ee2d2c62bc36375f5da4 = L.geoJson(null, {
#                 onEachFeature: geo_json_6723416e2b11ee2d2c62bc36375f5da4_onEachFeature,
#
#                 style: geo_json_6723416e2b11ee2d2c62bc36375f5da4_styler,
#                 pointToLayer: geo_json_6723416e2b11ee2d2c62bc36375f5da4_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_6723416e2b11ee2d2c62bc36375f5da4_add (data) {
#             geo_json_6723416e2b11ee2d2c62bc36375f5da4
#                 .addData(data);
#         }
#             geo_json_6723416e2b11ee2d2c62bc36375f5da4_add({&quot;bbox&quot;: [12.244877029138685, 51.26216406790087, 12.504129909612955, 51.40691028331796], &quot;features&quot;: [{&quot;bbox&quot;: [12.244877029138685, 51.26216406790087, 12.504129909612955, 51.40691028331796], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.504129909612955, 51.26216406790087], [12.504129909612955, 51.40691028331796], [12.244877029138685, 51.40691028331796], [12.244877029138685, 51.26216406790087], [12.504129909612955, 51.26216406790087]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5157&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_6723416
